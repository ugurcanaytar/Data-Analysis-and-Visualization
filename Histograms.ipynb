# %%
# Standard
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
# Stats
from scipy import stats

# %%
# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([  3.,   4.,   8.,  13.,   9.,  15.,  12.,  17.,  15.,   4.]),
#  array([-2.29045503, -1.88984948, -1.48924393, -1.08863838, -0.68803283,
#         -0.28742728,  0.11317827,  0.51378382,  0.91438937,  1.31499492,
#          1.71560047]),
#  <a list of 10 Patch objects>)

# %%
dataset2 = randn(80)
plt.hist(dataset2, color = 'indianred')
# Out:
# (array([  1.,   5.,   1.,   4.,  12.,  17.,  12.,  10.,  13.,   5.]),
#  array([-2.66483531, -2.2275229 , -1.79021048, -1.35289806, -0.91558564,
#         -0.47827323, -0.04096081,  0.39635161,  0.83366402,  1.27097644,
#          1.70828886]),
#  <a list of 10 Patch objects>)

# %%
# normed for normalization datasets (one has 80 another has 100)
#alpha gives transparency
#bins = çubuklar
plt.hist(dataset1, normed = True, color = 'indianred', alpha=0.5, bins = 20) 
plt.hist(dataset2, normed = True, alpha = 0.5, bins = 20)
# Out:
# (array([  1.,   0.,   1.,   4.,   0.,   1.,   2.,   2.,   6.,   6.,   7.,
#          10.,   3.,   9.,   8.,   2.,   6.,   7.,   4.,   1.]),
#  array([-2.66483531, -2.44617911, -2.2275229 , -2.00886669, -1.79021048,
#         -1.57155427, -1.35289806, -1.13424185, -0.91558564, -0.69692944,
#         -0.47827323, -0.25961702, -0.04096081,  0.1776954 ,  0.39635161,
#          0.61500782,  0.83366402,  1.05232023,  1.27097644,  1.48963265,
#          1.70828886]),
#  <a list of 20 Patch objects>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(datata1, data2)

# %%
sns.jointplot(data1, data2, kind='hex')
